# %%
import pandas
x_2003 = pandas.read_stata('23600-0002-Data.dta').drop(columns =['STATNUM','VTYP_O9','VTYP_S9','VTYP_R9','ORINIBRS','ORIADDDT','CORECTY','VTYP_G9','VTYP_U9','VTYP_B9','VTYP_F9','VTYP_I10','VTYP_B10','VTYP_F10','VTYP_G10','VTYP_G8','VTYP_F8','VTYP_B8','VTYP_I8','VTYP_U7','VTYP_O7','VTYP_S7','VTYP_R7','VTYP_G7','VTYP_F7','VTYP_B7','VTYP_R8','VTYP_O6','VTYP_S6','VTYP_I7','VTYP_S8','VTYP_O8','VTYP_U8','COVBYORI','VTYP_I6','VTYP_U5','VTYP_B6','VTYP_O5','VTYP_S5','VTYP_R5','VTYP_G5','VTYP_F5','VTYP_B5','VTYP_I5','VTYP_U4','VTYP_O4','VTYP_S4','VTYP_F6','VTYP_G6','VTYP_F4','VTYP_B4','VTYP_G4','VTYP_R4','VTYP_R6','VTYP_U6','VTYP_I9','VTYP_R10','VTYP_F3','VTYP_G3','VTYP_R3','VTYP_S3','VTYP_O3','VTYP_U3','VTYP_I4','VTYP_S10','VTYP_O10','VTYP_U10','VTYP_B3','VTYP_U1','VTYP_U2','VTYP_I2','VTYP_B2','VTYP_F2','VTYP_G2','VTYP_B1','VTYP_F1','VTYP_G1','VTYP_R1','VTYP_S1','VTYP_O1','VTYP_R2','VTYP_S2','VTYP_O2','VTYP_I3','BIASMO8','OFFCOD9','NUMVTM9','LOCCOD9','BIASMO9','OFFCOD10','NUMVTM10','LOCCOD10','BIASMO10','VTYP_I1','NUMVTM6','LOCCOD6','BIASMO6','OFFCOD7','NUMVTM7','LOCCOD7','BIASMO7','OFFCOD8','NUMVTM8','LOCCOD8','BIASMO3','OFFCOD4','NUMVTM4','LOCCOD4','BIASMO4','OFFCOD5','NUMVTM5','LOCCOD5','BIASMO5','OFFCOD6','LOCCOD3','NUMVTM3','OFFCOD3','BIASMO2','LOCCOD2','NUMVTM2','OFFCOD2','NBRSFLG','INCIDDTE','DATASRC','FIELDNO','DIVISN','POPGRP','GOFFRAC','TNUMOFF','TNUMVTMS','CFIPS2','CFIPS3','CFIPS4','CFIPS5','MSA1','COUNTY1','INACTDTE','REC_IR','AGINDIC','OFFCOD1','NUMVTM1','CFIPS1','AGNAME','F4QACT','F3QACT','POP2','LSTPOP1','COUNTY2','MSA2','LSTPOP2','POP3','COUNTY3','MSA3','QTR1ACT','QTR2ACT','QTR3ACT','QTR4ACT','F1QACT','F2QACT','LSTPOP5','MSA5','COUNTY5','POP5','LSTPOP4','COUNTY4','POP4','LSTPOP3','MSA4','IINCIDNO'])

new_x_2003 = x_2003.rename(columns = {'BIASMO1':'BIAS MOTIVATION', 'LOCCOD1':'LOCATION', 'MASTERYR':'YEAR', 'ORI':'AGENCY IDENTIFIER', 'STATECOD':'STATE', 'JUDDIST':'JUDICIAL DISTRICT', 'POP1': 'POPULATION'})

new_x_2003['BIAS MOTIVATION'] = new_x_2003['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Catholic','Anti-Islamic', 'Anti-Jewish', "Anti-Jehovah's Witness", 'Anti-Other Christian', 'Anti-Hindu', 'Anti-Mormon','Anti-Buddhist', 'Anti-Other Religion', 'Anti-Multi-Religious', 'Anti-Protestant', 'Anti-Sikh','Anti-Atheism/Agnosticism'],'Anti-Religion'))
new_x_2003['BIAS MOTIVATION'] = new_x_2003['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Other ethnicity','Anti-Hispanic', 'Anti-Black', 'Anti-Am Indian', 'Anti-Asian', 'Anti-White', 'Anti-Multi-Racial'], 'Anti-Race'))
new_x_2003['BIAS MOTIVATION'] = new_x_2003['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Lesbian, Gay, Bisexual, or Transgender','Anti-Female Homosexual', 'Anti-Heterosexual', 'Anti-Transgender','Anti-Bisexual', 'Anti-Male Homosexual','Anti-Homosexual (both)'], 'Anti-Sexual Orientation'))
new_x_2003['BIAS MOTIVATION'] = new_x_2003['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Mental Disability','Anti-Physical Disability']))

new_x_2003
# Out:
#      AGENCY IDENTIFIER       CITY STATE REGION JUDICIAL DISTRICT  POPULATION  \
# 0            AK0010100  ANCHORAGE    AK   West              020A      271085
# 1            AK0010100  ANCHORAGE    AK   West              020A      271085
# 2            AK0010100  ANCHORAGE    AK   West              020A      271085
# 3            AK0010100  ANCHORAGE    AK   West              020A      271085
# 4            AK0010100  ANCHORAGE    AK   West              020A      271085
# ...                ...        ...   ...    ...               ...         ...
# 7484         WY0110100   CHEYENNE    WY   West              450A       53931
# 7485         WY0110100   CHEYENNE    WY   West              450A       53931
# 7486         WY0110100   CHEYENNE    WY   West              450A       53931
# 7487         WY0130100     CASPER    WY   West              450A       50279
# 7488         WY0150200     POWELL    WY   West              450A        5282
#
# ...

# %%
x_2000 = pandas.read_stata('23783-0002-Data.dta').drop(columns =['STATNUM','VTYP_O9','VTYP_S9','VTYP_R9','ORINIBRS','ORIADDDT','CORECTY','VTYP_G9','VTYP_U9','VTYP_B9','VTYP_F9','VTYP_I10','VTYP_B10','VTYP_F10','VTYP_G10','VTYP_G8','VTYP_F8','VTYP_B8','VTYP_I8','VTYP_U7','VTYP_O7','VTYP_S7','VTYP_R7','VTYP_G7','VTYP_F7','VTYP_B7','VTYP_R8','VTYP_O6','VTYP_S6','VTYP_I7','VTYP_S8','VTYP_O8','VTYP_U8','COVBYORI','VTYP_I6','VTYP_U5','VTYP_B6','VTYP_O5','VTYP_S5','VTYP_R5','VTYP_G5','VTYP_F5','VTYP_B5','VTYP_I5','VTYP_U4','VTYP_O4','VTYP_S4','VTYP_F6','VTYP_G6','VTYP_F4','VTYP_B4','VTYP_G4','VTYP_R4','VTYP_R6','VTYP_U6','VTYP_I9','VTYP_R10','VTYP_F3','VTYP_G3','VTYP_R3','VTYP_S3','VTYP_O3','VTYP_U3','VTYP_I4','VTYP_S10','VTYP_O10','VTYP_U10','VTYP_B3','VTYP_U1','VTYP_U2','VTYP_I2','VTYP_B2','VTYP_F2','VTYP_G2','VTYP_B1','VTYP_F1','VTYP_G1','VTYP_R1','VTYP_S1','VTYP_O1','VTYP_R2','VTYP_S2','VTYP_O2','VTYP_I3','BIASMO8','OFFCOD9','NUMVTM9','LOCCOD9','BIASMO9','OFFCOD10','NUMVTM10','LOCCOD10','BIASMO10','VTYP_I1','NUMVTM6','LOCCOD6','BIASMO6','OFFCOD7','NUMVTM7','LOCCOD7','BIASMO7','OFFCOD8','NUMVTM8','LOCCOD8','BIASMO3','OFFCOD4','NUMVTM4','LOCCOD4','BIASMO4','OFFCOD5','NUMVTM5','LOCCOD5','BIASMO5','OFFCOD6','LOCCOD3','NUMVTM3','OFFCOD3','BIASMO2','LOCCOD2','NUMVTM2','OFFCOD2','NBRSFLG','INCIDDTE','DATASRC','FIELDNO','DIVISN','POPGRP','GOFFRAC','TNUMOFF','TNUMVTMS','CFIPS2','CFIPS3','CFIPS4','CFIPS5','MSA1','COUNTY1','INACTDTE','REC_IR','AGINDIC','OFFCOD1','NUMVTM1','CFIPS1','AGNAME','F4QACT','F3QACT','POP2','LSTPOP1','COUNTY2','MSA2','LSTPOP2','POP3','COUNTY3','MSA3','QTR1ACT','QTR2ACT','QTR3ACT','QTR4ACT','F1QACT','F2QACT','LSTPOP5','MSA5','COUNTY5','POP5','LSTPOP4','COUNTY4','POP4','LSTPOP3','MSA4','IINCIDNO'])
new_x_2000 = x_2000.rename(columns = {'BIASMO1':'BIAS MOTIVATION', 'LOCCOD1':'LOCATION', 'MASTERYR':'YEAR', 'ORI':'AGENCY IDENTIFIER', 'STATECOD':'STATE', 'JUDDIST':'JUDICIAL DISTRICT', 'POP1': 'POPULATION'})

new_x_2000['BIAS MOTIVATION'] = new_x_2000['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Catholic','Anti-Islamic', 'Anti-Jewish', "Anti-Jehovah's Witness", 'Anti-Other Christian', 'Anti-Hindu', 'Anti-Mormon','Anti-Buddhist', 'Anti-Other Religion', 'Anti-Multi-Religious', 'Anti-Protestant', 'Anti-Sikh','Anti-Atheism/Agnosticism'],'Anti-Religion'))
new_x_2000['BIAS MOTIVATION'] = new_x_2000['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Other ethnicity','Anti-Hispanic', 'Anti-Black', 'Anti-Am Indian', 'Anti-Asian', 'Anti-White', 'Anti-Multi-Racial'], 'Anti-Race'))
new_x_2000['BIAS MOTIVATION'] = new_x_2000['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Lesbian, Gay, Bisexual, or Transgender','Anti-Female Homosexual', 'Anti-Heterosexual', 'Anti-Transgender','Anti-Bisexual', 'Anti-Male Homosexual','Anti-Homosexual (both)'], 'Anti-Sexual Orientation'))
new_x_2000['BIAS MOTIVATION'] = new_x_2000['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Mental Disability','Anti-Physical Disability']))

new_x_2000
# Out:
#      AGENCY IDENTIFIER          CITY STATE REGION JUDICIAL DISTRICT  \
# 0            AK0010100     ANCHORAGE    AK   West              020A
# 1            AK0010100     ANCHORAGE    AK   West              020A
# 2            AK0010100     ANCHORAGE    AK   West              020A
# 3            AK0010100     ANCHORAGE    AK   West              020A
# 4            AR0080300  GREEN FOREST    AR  South              035W
# ...                ...           ...   ...    ...               ...
# 8058         WY0150100          CODY    WY   West              450A
# 8059         WY0150100          CODY    WY   West              450A
# 8060         WY0150100          CODY    WY   West              450A
# 8061         WY0150100          CODY    WY   West              450A
# 8062         WY0150100          CODY    WY   West              450A
#
#       POPULATION  YEAR     QUARTER            LOCATION BIAS MOTIVATION
# 0         260900  2000  Jul to Sep      Residence/home       Anti-Race
# ...

# %%
x_2001 = pandas.read_stata('23781-0002-Data.dta').drop(columns =['STATNUM','VTYP_O9','VTYP_S9','VTYP_R9','ORINIBRS','ORIADDDT','CORECTY','VTYP_G9','VTYP_U9','VTYP_B9','VTYP_F9','VTYP_I10','VTYP_B10','VTYP_F10','VTYP_G10','VTYP_G8','VTYP_F8','VTYP_B8','VTYP_I8','VTYP_U7','VTYP_O7','VTYP_S7','VTYP_R7','VTYP_G7','VTYP_F7','VTYP_B7','VTYP_R8','VTYP_O6','VTYP_S6','VTYP_I7','VTYP_S8','VTYP_O8','VTYP_U8','COVBYORI','VTYP_I6','VTYP_U5','VTYP_B6','VTYP_O5','VTYP_S5','VTYP_R5','VTYP_G5','VTYP_F5','VTYP_B5','VTYP_I5','VTYP_U4','VTYP_O4','VTYP_S4','VTYP_F6','VTYP_G6','VTYP_F4','VTYP_B4','VTYP_G4','VTYP_R4','VTYP_R6','VTYP_U6','VTYP_I9','VTYP_R10','VTYP_F3','VTYP_G3','VTYP_R3','VTYP_S3','VTYP_O3','VTYP_U3','VTYP_I4','VTYP_S10','VTYP_O10','VTYP_U10','VTYP_B3','VTYP_U1','VTYP_U2','VTYP_I2','VTYP_B2','VTYP_F2','VTYP_G2','VTYP_B1','VTYP_F1','VTYP_G1','VTYP_R1','VTYP_S1','VTYP_O1','VTYP_R2','VTYP_S2','VTYP_O2','VTYP_I3','BIASMO8','OFFCOD9','NUMVTM9','LOCCOD9','BIASMO9','OFFCOD10','NUMVTM10','LOCCOD10','BIASMO10','VTYP_I1','NUMVTM6','LOCCOD6','BIASMO6','OFFCOD7','NUMVTM7','LOCCOD7','BIASMO7','OFFCOD8','NUMVTM8','LOCCOD8','BIASMO3','OFFCOD4','NUMVTM4','LOCCOD4','BIASMO4','OFFCOD5','NUMVTM5','LOCCOD5','BIASMO5','OFFCOD6','LOCCOD3','NUMVTM3','OFFCOD3','BIASMO2','LOCCOD2','NUMVTM2','OFFCOD2','NBRSFLG','INCIDDTE','DATASRC','FIELDNO','DIVISN','POPGRP','GOFFRAC','TNUMOFF','TNUMVTMS','CFIPS2','CFIPS3','CFIPS4','CFIPS5','MSA1','COUNTY1','INACTDTE','REC_IR','AGINDIC','OFFCOD1','NUMVTM1','CFIPS1','AGNAME','F4QACT','F3QACT','POP2','LSTPOP1','COUNTY2','MSA2','LSTPOP2','POP3','COUNTY3','MSA3','QTR1ACT','QTR2ACT','QTR3ACT','QTR4ACT','F1QACT','F2QACT','LSTPOP5','MSA5','COUNTY5','POP5','LSTPOP4','COUNTY4','POP4','LSTPOP3','MSA4','IINCIDNO'])
new_x_2001 = x_2001.rename(columns = {'BIASMO1':'BIAS MOTIVATION', 'LOCCOD1':'LOCATION', 'MASTERYR':'YEAR', 'ORI':'AGENCY IDENTIFIER', 'STATECOD':'STATE', 'JUDDIST':'JUDICIAL DISTRICT', 'POP1': 'POPULATION'})

new_x_2001['BIAS MOTIVATION'] = new_x_2001['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Catholic','Anti-Islamic', 'Anti-Jewish', "Anti-Jehovah's Witness", 'Anti-Other Christian', 'Anti-Hindu', 'Anti-Mormon','Anti-Buddhist', 'Anti-Other Religion', 'Anti-Multi-Religious', 'Anti-Protestant', 'Anti-Sikh','Anti-Atheism/Agnosticism'],'Anti-Religion'))
new_x_2001['BIAS MOTIVATION'] = new_x_2001['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Other ethnicity','Anti-Hispanic', 'Anti-Black', 'Anti-Am Indian', 'Anti-Asian', 'Anti-White', 'Anti-Multi-Racial'], 'Anti-Race'))
new_x_2001['BIAS MOTIVATION'] = new_x_2001['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Lesbian, Gay, Bisexual, or Transgender','Anti-Female Homosexual', 'Anti-Heterosexual', 'Anti-Transgender','Anti-Bisexual', 'Anti-Male Homosexual','Anti-Homosexual (both)'], 'Anti-Sexual Orientation'))
new_x_2001['BIAS MOTIVATION'] = new_x_2001['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Mental Disability','Anti-Physical Disability']))




new_x_2001
# Out:
#      AGENCY IDENTIFIER          CITY STATE REGION JUDICIAL DISTRICT  \
# 0            AK0010100     ANCHORAGE    AK   West              020A
# 1            AK0010100     ANCHORAGE    AK   West              020A
# 2            AK0010100     ANCHORAGE    AK   West              020A
# 3            AK0010100     ANCHORAGE    AK   West              020A
# 4            AK0010100     ANCHORAGE    AK   West              020A
# ...                ...           ...   ...    ...               ...
# 9725         WY0090100   THERMOPOLIS    WY   West              450A
# 9726         WY0130100        CASPER    WY   West              450A
# 9727         WY0150100          CODY    WY   West              450A
# 9728         WY0190200  ROCK SPRINGS    WY   West              450A
# 9729         WY0230100     NEWCASTLE    WY   West              450A
#
#       POPULATION  YEAR     QUARTER            LOCATION  \
# 0         263588  2001  Jan to Mar  Highway/road/alley
# ...

# %%
x_2004 = pandas.read_stata('23544-0002-Data.dta').drop(columns =['STATNUM','VTYP_O9','VTYP_S9','VTYP_R9','ORINIBRS','ORIADDDT','CORECTY','VTYP_G9','VTYP_U9','VTYP_B9','VTYP_F9','VTYP_I10','VTYP_B10','VTYP_F10','VTYP_G10','VTYP_G8','VTYP_F8','VTYP_B8','VTYP_I8','VTYP_U7','VTYP_O7','VTYP_S7','VTYP_R7','VTYP_G7','VTYP_F7','VTYP_B7','VTYP_R8','VTYP_O6','VTYP_S6','VTYP_I7','VTYP_S8','VTYP_O8','VTYP_U8','COVBYORI','VTYP_I6','VTYP_U5','VTYP_B6','VTYP_O5','VTYP_S5','VTYP_R5','VTYP_G5','VTYP_F5','VTYP_B5','VTYP_I5','VTYP_U4','VTYP_O4','VTYP_S4','VTYP_F6','VTYP_G6','VTYP_F4','VTYP_B4','VTYP_G4','VTYP_R4','VTYP_R6','VTYP_U6','VTYP_I9','VTYP_R10','VTYP_F3','VTYP_G3','VTYP_R3','VTYP_S3','VTYP_O3','VTYP_U3','VTYP_I4','VTYP_S10','VTYP_O10','VTYP_U10','VTYP_B3','VTYP_U1','VTYP_U2','VTYP_I2','VTYP_B2','VTYP_F2','VTYP_G2','VTYP_B1','VTYP_F1','VTYP_G1','VTYP_R1','VTYP_S1','VTYP_O1','VTYP_R2','VTYP_S2','VTYP_O2','VTYP_I3','BIASMO8','OFFCOD9','NUMVTM9','LOCCOD9','BIASMO9','OFFCOD10','NUMVTM10','LOCCOD10','BIASMO10','VTYP_I1','NUMVTM6','LOCCOD6','BIASMO6','OFFCOD7','NUMVTM7','LOCCOD7','BIASMO7','OFFCOD8','NUMVTM8','LOCCOD8','BIASMO3','OFFCOD4','NUMVTM4','LOCCOD4','BIASMO4','OFFCOD5','NUMVTM5','LOCCOD5','BIASMO5','OFFCOD6','LOCCOD3','NUMVTM3','OFFCOD3','BIASMO2','LOCCOD2','NUMVTM2','OFFCOD2','NBRSFLG','INCIDDTE','DATASRC','FIELDNO','DIVISN','POPGRP','GOFFRAC','TNUMOFF','TNUMVTMS','CFIPS2','CFIPS3','CFIPS4','CFIPS5','MSA1','COUNTY1','INACTDTE','REC_IR','AGINDIC','OFFCOD1','NUMVTM1','CFIPS1','AGNAME','F4QACT','F3QACT','POP2','LSTPOP1','COUNTY2','MSA2','LSTPOP2','POP3','COUNTY3','MSA3','QTR1ACT','QTR2ACT','QTR3ACT','QTR4ACT','F1QACT','F2QACT','LSTPOP5','MSA5','COUNTY5','POP5','LSTPOP4','COUNTY4','POP4','LSTPOP3','MSA4','IINCIDNO'])
new_x_2004 = x_2004.rename(columns = {'BIASMO1':'BIAS MOTIVATION', 'LOCCOD1':'LOCATION', 'MASTERYR':'YEAR', 'ORI':'AGENCY IDENTIFIER', 'STATECOD':'STATE', 'JUDDIST':'JUDICIAL DISTRICT', 'POP1': 'POPULATION'})


new_x_2004['BIAS MOTIVATION'] = new_x_2004['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Catholic','Anti-Islamic', 'Anti-Jewish', "Anti-Jehovah's Witness", 'Anti-Other Christian', 'Anti-Hindu', 'Anti-Mormon','Anti-Buddhist', 'Anti-Other Religion', 'Anti-Multi-Religious', 'Anti-Protestant', 'Anti-Sikh','Anti-Atheism/Agnosticism'],'Anti-Religion'))
new_x_2004['BIAS MOTIVATION'] = new_x_2004['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Other ethnicity','Anti-Hispanic', 'Anti-Black', 'Anti-Am Indian', 'Anti-Asian', 'Anti-White', 'Anti-Multi-Racial'], 'Anti-Race'))
new_x_2004['BIAS MOTIVATION'] = new_x_2004['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Lesbian, Gay, Bisexual, or Transgender','Anti-Female Homosexual', 'Anti-Heterosexual', 'Anti-Transgender','Anti-Bisexual', 'Anti-Male Homosexual','Anti-Homosexual (both)'], 'Anti-Sexual Orientation'))
new_x_2004['BIAS MOTIVATION'] = new_x_2004['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Mental Disability','Anti-Physical Disability']))

new_x_2004
# Out:
#      AGENCY IDENTIFIER         CITY STATE REGION JUDICIAL DISTRICT  \
# 0            AK0010100    ANCHORAGE    AK   West              020A
# 1            AK0010100    ANCHORAGE    AK   West              020A
# 2            AK0010100    ANCHORAGE    AK   West              020A
# 3            AK0010100    ANCHORAGE    AK   West              020A
# 4            AK0010100    ANCHORAGE    AK   West              020A
# ...                ...          ...   ...    ...               ...
# 7644         WV0410100      BECKLEY    WV  South              435S
# 7645         WY0030100     GILLETTE    WY   West              450A
# 7646         WY0110100     CHEYENNE    WY   West              450A
# 7647         WY0130100       CASPER    WY   West              450A
# 7648         WY0190100  GREEN RIVER    WY   West              450A
#
#       POPULATION  YEAR     QUARTER              LOCATION BIAS MOTIVATION
# 0         273714  2004  Jan to Mar           Field/woods       Anti-Race
# ...

# %%
x_2002 = pandas.read_stata('23625-0002-Data.dta').drop(columns =['STATNUM','VTYP_O9','VTYP_S9','VTYP_R9','ORINIBRS','ORIADDDT','CORECTY','VTYP_G9','VTYP_U9','VTYP_B9','VTYP_F9','VTYP_I10','VTYP_B10','VTYP_F10','VTYP_G10','VTYP_G8','VTYP_F8','VTYP_B8','VTYP_I8','VTYP_U7','VTYP_O7','VTYP_S7','VTYP_R7','VTYP_G7','VTYP_F7','VTYP_B7','VTYP_R8','VTYP_O6','VTYP_S6','VTYP_I7','VTYP_S8','VTYP_O8','VTYP_U8','COVBYORI','VTYP_I6','VTYP_U5','VTYP_B6','VTYP_O5','VTYP_S5','VTYP_R5','VTYP_G5','VTYP_F5','VTYP_B5','VTYP_I5','VTYP_U4','VTYP_O4','VTYP_S4','VTYP_F6','VTYP_G6','VTYP_F4','VTYP_B4','VTYP_G4','VTYP_R4','VTYP_R6','VTYP_U6','VTYP_I9','VTYP_R10','VTYP_F3','VTYP_G3','VTYP_R3','VTYP_S3','VTYP_O3','VTYP_U3','VTYP_I4','VTYP_S10','VTYP_O10','VTYP_U10','VTYP_B3','VTYP_U1','VTYP_U2','VTYP_I2','VTYP_B2','VTYP_F2','VTYP_G2','VTYP_B1','VTYP_F1','VTYP_G1','VTYP_R1','VTYP_S1','VTYP_O1','VTYP_R2','VTYP_S2','VTYP_O2','VTYP_I3','BIASMO8','OFFCOD9','NUMVTM9','LOCCOD9','BIASMO9','OFFCOD10','NUMVTM10','LOCCOD10','BIASMO10','VTYP_I1','NUMVTM6','LOCCOD6','BIASMO6','OFFCOD7','NUMVTM7','LOCCOD7','BIASMO7','OFFCOD8','NUMVTM8','LOCCOD8','BIASMO3','OFFCOD4','NUMVTM4','LOCCOD4','BIASMO4','OFFCOD5','NUMVTM5','LOCCOD5','BIASMO5','OFFCOD6','LOCCOD3','NUMVTM3','OFFCOD3','BIASMO2','LOCCOD2','NUMVTM2','OFFCOD2','NBRSFLG','INCIDDTE','DATASRC','FIELDNO','DIVISN','POPGRP','GOFFRAC','TNUMOFF','TNUMVTMS','CFIPS2','CFIPS3','CFIPS4','CFIPS5','MSA1','COUNTY1','INACTDTE','REC_IR','AGINDIC','OFFCOD1','NUMVTM1','CFIPS1','AGNAME','F4QACT','F3QACT','POP2','LSTPOP1','COUNTY2','MSA2','LSTPOP2','POP3','COUNTY3','MSA3','QTR1ACT','QTR2ACT','QTR3ACT','QTR4ACT','F1QACT','F2QACT','LSTPOP5','MSA5','COUNTY5','POP5','LSTPOP4','COUNTY4','POP4','LSTPOP3','MSA4','IINCIDNO'])
new_x_2002 = x_2002.rename(columns = {'BIASMO1':'BIAS MOTIVATION', 'LOCCOD1':'LOCATION', 'MASTERYR':'YEAR', 'ORI':'AGENCY IDENTIFIER', 'STATECOD':'STATE', 'JUDDIST':'JUDICIAL DISTRICT', 'POP1': 'POPULATION'})

new_x_2002['BIAS MOTIVATION'] = new_x_2002['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Catholic','Anti-Islamic', 'Anti-Jewish', "Anti-Jehovah's Witness", 'Anti-Other Christian', 'Anti-Hindu', 'Anti-Mormon','Anti-Buddhist', 'Anti-Other Religion', 'Anti-Multi-Religious', 'Anti-Protestant', 'Anti-Sikh','Anti-Atheism/Agnosticism'],'Anti-Religion'))
new_x_2002['BIAS MOTIVATION'] = new_x_2002['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Other ethnicity','Anti-Hispanic', 'Anti-Black', 'Anti-Am Indian', 'Anti-Asian', 'Anti-White', 'Anti-Multi-Racial'], 'Anti-Race'))
new_x_2002['BIAS MOTIVATION'] = new_x_2002['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Lesbian, Gay, Bisexual, or Transgender','Anti-Female Homosexual', 'Anti-Heterosexual', 'Anti-Transgender','Anti-Bisexual', 'Anti-Male Homosexual','Anti-Homosexual (both)'], 'Anti-Sexual Orientation'))
new_x_2002['BIAS MOTIVATION'] = new_x_2002['BIAS MOTIVATION'].replace(dict.fromkeys(['Anti-Mental Disability','Anti-Physical Disability']))

new_x_2002
# Out:
#      AGENCY IDENTIFIER       CITY STATE REGION JUDICIAL DISTRICT  POPULATION  \
# 0            AK0010100  ANCHORAGE    AK   West              020A      267280
# 1            AK0010100  ANCHORAGE    AK   West              020A      267280
# 2            AK0010100  ANCHORAGE    AK   West              020A      267280
# 3            AK0010100  ANCHORAGE    AK   West              020A      267280
# 4            AK0010100  ANCHORAGE    AK   West              020A      267280
# ...                ...        ...   ...    ...               ...         ...
# 7457         WY0030000   GILLETTE    WY   West              450A       14192
# 7458         WY0030100   GILLETTE    WY   West              450A       19842
# 7459         WY0050000    DOUGLAS    WY   West              450A        4578
# 7460         WY0110100   CHEYENNE    WY   West              450A       53539
# 7461         WY0110100   CHEYENNE    WY   West              450A       53539
#
# ...
