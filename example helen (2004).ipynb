# %%
import os
import pandas as pd
import numpy as np
import re

# %%
#loading in the dataset 
df = pd.read_excel('Table1 2004.xls')

# %%
#renaming the column names 
df = df.rename(columns={"Table 1": "Bias motivation", "Unnamed: 1": "Incidents", "Unnamed: 2": "Offenses", 
                  "Unnamed: 3": "Victims", "Unnamed: 4": "Known Offenders"})

# %%
#removing unneeded rows and resetting the index 
df = df.loc[5:30, :].set_index('Bias motivation')

# %%
df = df.rename(index=lambda s: re.sub(r'\d+$', '', s)) #removing any digits inside the index column 
df
# Out:
#                                      Incidents Offenses Victims  \
# Bias motivation
# Anti-White                                 829      998    1027
# Anti-Black                                2731     3281    3475
# Anti-American Indian/Alaskan Native         83       97     100
# Anti-Asian/Pacific Islander                217      252     266
# Anti-Multiple Races, Group                 182      235     251
# Religion:                                 1374     1480    1586
# Anti-Jewish                                954     1003    1076
# Anti-Catholic                               57       57      68
# Anti-Protestant                             38       43      48
# Anti-Islamic                               156      193     201
# Anti-Other Religion                        128      140     147
# Anti-Multiple Religions, Group              35       37      39
# Anti-Atheism/Agnosticism/etc.                6        7       7
# ...

# %%
#dropping rows that are not needed (the totals)
df = df.drop(df.index[5])
df = df.drop(df.index[12])
df = df.drop(df.index[-4])
df = df.drop(df.index[-6])

df
# Out:
#                                      Incidents Offenses Victims  \
# Bias motivation
# Anti-White                                 829      998    1027
# Anti-Black                                2731     3281    3475
# Anti-American Indian/Alaskan Native         83       97     100
# Anti-Asian/Pacific Islander                217      252     266
# Anti-Multiple Races, Group                 182      235     251
# Anti-Jewish                                954     1003    1076
# Anti-Catholic                               57       57      68
# Anti-Protestant                             38       43      48
# Anti-Islamic                               156      193     201
# Anti-Other Religion                        128      140     147
# Anti-Multiple Religions, Group              35       37      39
# Anti-Atheism/Agnosticism/etc.                6        7       7
# Anti-Male Homosexual                       738      855     902
# ...

# %%
race = df[:5]
race
# Out:
#                                     Incidents Offenses Victims Known Offenders
# Bias motivation
# Anti-White                                829      998    1027            1085
# Anti-Black                               2731     3281    3475            2694
# Anti-American Indian/Alaskan Native        83       97     100              97
# Anti-Asian/Pacific Islander               217      252     266             188
# Anti-Multiple Races, Group                182      235     251             109

# %%
religion = df[5:12]
religion
# Out:
#                                Incidents Offenses Victims Known Offenders
# Bias motivation
# Anti-Jewish                          954     1003    1076             330
# Anti-Catholic                         57       57      68              37
# Anti-Protestant                       38       43      48              28
# Anti-Islamic                         156      193     201             124
# Anti-Other Religion                  128      140     147              68
# Anti-Multiple Religions, Group        35       37      39              14
# Anti-Atheism/Agnosticism/etc.          6        7       7               3

# %%
sexual_orientation = df[12:17]
sexual_orientation
# Out:
#                        Incidents Offenses Victims Known Offenders
# Bias motivation
# Anti-Male Homosexual         738      855     902             832
# Anti-Female Homosexual       164      201     212             163
# Anti-Homosexual              245      297     314             224
# Anti-Heterosexual             33       35      36              22
# Anti-Bisexual                 17       18      18              17

# %%
ethnicity = df[17:19]
ethnicity
# Out:
#                                      Incidents Offenses Victims  \
# Bias motivation
# Anti-Hispanic                              475      611     646
# Anti-Other Ethnicity/National Origin       497      590     608
#
#                                      Known Offenders
# Bias motivation
# Anti-Hispanic                                    585
# Anti-Other Ethnicity/National Origin             462

# %%
disability = df[-3:-1]
disability
# Out:
#                 Incidents Offenses Victims Known Offenders
# Bias motivation
# Anti-Physical          23       23      24              16
# Anti-Mental            34       48      49              38
