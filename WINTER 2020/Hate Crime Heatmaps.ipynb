# %%
import os
import pandas as pd
import numpy as np
import re
import plotly.graph_objects as go

# %%
ml = pd.read_csv('merged.csv')

# %%
#states = ml.get("STATE")
#states.values

# %%
ml.groupby('STATE').count()
# Out:
#        AGENCY IDENTIFIER  BIAS MOTIVATION   CITY  JUDICIAL DISTRICT  LOCATION  \
# STATE
# AK                   142              142    142                142       142
# AL                   180              180    180                180       180
# AR                   892              887    892                892       892
# AZ                  3700             3688   3700               3700      3700
# CA                 21589            21565  21589              21581     21589
# CO                  2205             2199   2205               2205      2205
# CT                  2321             2311   2321               2321      2321
# DC                   869              868    869                869       869
# DE                   447              446    447                447       447
# FL                  2927             2926   2927               2926      2927
# GA                   456              453    456                456       456
# ...

# %%
states = ml["STATE"].value_counts().to_frame().reset_index()
states.columns
states
# Out:
#    index  STATE
# 0     CA  21589
# 1     NJ   9808
# 2     NY   9694
# 3     MI   7700
# 4     MA   6477
# 5     OH   5275
# 6     WA   4069
# 7     TX   3980
# 8     VA   3916
# 9     AZ   3700
# 10    TN   3358
# 11    FL   2927
# 12    MN   2670
# 13    IL   2418
# 14    CT   2321
# 15    MD   2222
# 16    CO   2205
# 17    KY   2024
# 18    OR   2021
# 19    NC   1704
# 20    MO   1548
# 21    SC   1433
# 22    PA   1387
# 23    KS   1252
# 24    NV   1240
# 25    IN   1111
# 26    UT   1003
# 27    WI    974
# 28    AR    892
# 29    DC    869
# 30    ME    842
# 31    NB    748
# 32    OK    737
# 33    WV    639
# 34    ID    552
# 35    NH    508
# 36    MT    485
# 37    RI    467
# 38    GA    456
# 39    DE    447
# 40    SD    406
# 41    IA    398
# 42    ND    355
# 43    LA    333
# 44    VT    325
# 45    NM    276
# 46    AL    180
# 47    AK    142
# 48    WY     95
# 49    MS     72
# 50    GM      5

# %%
fig = go.Figure(data=go.Choropleth(
    locations=states['index'], # Spatial coordinates
    z = states['STATE'].astype(float), # Data to be color-coded
    locationmode = 'USA-states', # set of locations match entries in `locations`
    colorscale = 'Reds',
    colorbar_title = "Number of Hate Crime",
    text=df['text']
))

fig.update_layout(
    title_text = 'Hate Crime Frequency by State',
    geo_scope='usa', # limite map scope to USA
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-21ec8a345c09> in <module>
#       5     colorscale = 'Reds',
#       6     colorbar_title = "Number of Hate Crime",
# ----> 7     text=df['text']
#       8 ))
#       9
#
# NameError: name 'df' is not defined

# %%
anti_race = ml[ml.get("BIAS MOTIVATION") == "Anti-Race"]

# %%
states_race = anti_race["STATE"].value_counts().to_frame().reset_index()
states_race.columns

# %%
fig = go.Figure(data=go.Choropleth(
    locations=states_race['index'], # Spatial coordinates
    z = states_race['STATE'].astype(float), # Data to be color-coded
    locationmode = 'USA-states', # set of locations match entries in `locations`
    colorscale = 'Reds',
    colorbar_title = "Number of Hate Crime",
))

fig.update_layout(
    title_text = 'Anti-Race Hate Crime Frequency by State',
    geo_scope='usa', # limite map scope to USA
)

fig.show()
