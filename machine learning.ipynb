# %%
import pandas as pd

# %%
df = pd.read_stata('2002_ML.dta')

# %%
#dropping columns with NaN's 
df = df.dropna(axis = 1)

# %%
df
# Out:
#      REC_IR  STATNUM        ORI  ORIADDDT       CITY STATECOD POPGRP  \
# 0        IR   Alaska  AK0010100  19910430  ANCHORAGE       AK     1C
# 1        IR   Alaska  AK0010100  19910430  ANCHORAGE       AK     1C
# 2        IR   Alaska  AK0010100  19910430  ANCHORAGE       AK     1C
# 3        IR   Alaska  AK0010100  19910430  ANCHORAGE       AK     1C
# 4        IR   Alaska  AK0010100  19910430  ANCHORAGE       AK     1C
# ...     ...      ...        ...       ...        ...      ...    ...
# 7457     IR  Wyoming  WY0030000  19910430   GILLETTE       WY     8C
# 7458     IR  Wyoming  WY0030100  19910430   GILLETTE       WY      5
# 7459     IR  Wyoming  WY0050000  19910430    DOUGLAS       WY     8D
# 7460     IR  Wyoming  WY0110100  19910430   CHEYENNE       WY      3
# 7461     IR  Wyoming  WY0110100  19910430   CHEYENNE       WY      3
#
#         DIVISN REGION AGINDIC CORECTY COVBYORI  FIELDNO JUDDIST NBRSFLG  \
# 0      Pacific   West    City       N              3030    020A
# ...
