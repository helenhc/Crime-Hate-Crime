# %%
import os
import pandas as pd
import numpy as np
import re

# %%
#table 2 
t2_10 = pd.read_excel('2010/Table2.xls')
t2_11 = pd.read_excel('2011/Table2.xls')
t2_12 = pd.read_excel('2012/Table2.xls')
t2_13 = pd.read_excel('2013/Table2.xls')
t2_14 = pd.read_excel('2014/Table2.xls')
t2_15 = pd.read_excel('2015/Table2.xls')
t2_16 = pd.read_excel('2016/Table2.xls')
t2_17 = pd.read_excel('2017/Table2.xls')
t2_18 = pd.read_excel('2018/Table2.xls')

# %%
#t2_10

# %%
table2 = [t2_10]
for index, df in enumerate(table2):
    table2[index] = df.rename(columns={"Table 2 ": "Offense type", "Unnamed: 1": "Incidents", "Unnamed: 2": "Offenses", 
                  "Unnamed: 3": "Victims", "Unnamed: 4": "Known Offenders"})
    table2[index] = table2[index].loc[3:18, :].set_index('Offense type')
    table2[index] = table2[index].rename(index=lambda s: re.sub(r'\d+$', '', s)) #removing any digits inside the index column 
[t2_10] = table2

# %%
#t2_10

# %%
#drop rows in tables
table2 = [t2_10]
for index, df in enumerate(table2):
    df = df.drop([df.index[0], df.index[7]])
    table2[index] = df
[t2_10] = table2

# %%
#t2_10

# %%
t2_11.columns
# Out:
# Index(['Table 2  ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
table2 = [t2_11, t2_12]
for index, df in enumerate(table2):
    table2[index] = df.rename(columns={"Table 2  ": "Offense type", "Unnamed: 1": "Incidents", "Unnamed: 2": "Offenses", 
                  "Unnamed: 3": "Victims", "Unnamed: 4": "Known Offenders"})
    table2[index] = table2[index].loc[4:19, :].set_index('Offense type')
    table2[index] = table2[index].rename(index=lambda s: re.sub(r'\d+$', '', s)) #removing any digits inside the index column 
[t2_11, t2_12] = table2

# %%
#t2_11

# %%
#drop rows in tables
table2 = [t2_11, t2_12]
for index, df in enumerate(table2):
    df = df.drop([df.index[0], df.index[7]])
    table2[index] = df
[t2_11, t2_12] = table2

# %%
#t2_13

# %%
table2 = [t2_13, t2_14, t2_15, t2_16]
for index, df in enumerate(table2):
    table2[index] = df.rename(columns={"Table 2  ": "Offense type", "Unnamed: 1": "Incidents", "Unnamed: 2": "Offenses", 
                  "Unnamed: 3": "Victims", "Unnamed: 4": "Known Offenders"})
    table2[index] = table2[index].loc[4:20, :].set_index('Offense type')
    table2[index] = table2[index].rename(index=lambda s: re.sub(r'\d+$', '', s)) #removing any digits inside the index column 
[t2_13, t2_14, t2_15, t2_16] = table2
t2_13
# Out:
#                                      Incidents Offenses Victims  \
# Offense type
# Crimes against persons:                   3607     4430    4430
# Murder and nonnegligent manslaughter         5        5       5
# Rape (revised definition)                   15       15      15
# Rape (legacy definition)                     6        6       6
# Aggravated assault                         588      734     734
# Simple assault                            1441     1720    1720
# Intimidation                              1528     1925    1925
# Other                                       24       25      25
# Crimes against property:                  2424     2424    2733
# Robbery                                    126      126     145
# Burglary                                   174      174     202
# Larceny-theft                              225      225     246
# Motor vehicle theft                         20       20      21
# Arson                                       36       36      40
# Destruction/damage/vandalism              1783     1783    2011
# Other                                       60       60      68
# Crimes against society                      79       79      79
#
#                                      Known Offenders
# Offense type
# Crimes against persons:                         4440
# Murder and nonnegligent manslaughter               5
# Rape (revised definition)                         15
# Rape (legacy definition)                          10
# Aggravated assault                               882
# Simple assault                                  2013
# Intimidation                                    1494
# Other                                             21
# Crimes against property:                        1527
# Robbery                                          261
# Burglary                                         164
# Larceny-theft                                    168
# Motor vehicle theft                                9
# Arson                                             21
# Destruction/damage/vandalism                     862
# Other                                             42
# Crimes against society                           102

# %%
t2_12.columns
# Out:
# Index(['Incidents', 'Offenses', 'Victims', 'Known Offenders'], dtype='object')

# %%
#drop rows in tables
table2 = [t2_13, t2_14, t2_15, t2_16]
for index, df in enumerate(table2):
    df = df.drop([df.index[0], df.index[8]])
    table2[index] = df
[t2_13, t2_14, t2_15, t2_16] = table2

# %%
t2_17
# Out:
#                                             Table 2    Unnamed: 1 Unnamed: 2  \
# 0   Incidents, Offenses, Victims, and Known Offenders         NaN        NaN
# 1                               by Offense Type, 2017         NaN        NaN
# 2                                        Offense type  Incidents1   Offenses
# 3                                               Total        7175       8437
# 4                             Crimes against persons:        4090       5084
# 5                Murder and nonnegligent manslaughter          12         15
# 6                                               Rape4          23         23
# 7                                  Aggravated assault         788        990
# 8                                      Simple assault        1433       1745
# 9                                        Intimidation        1807       2283
# 10             Human Trafficking, Commercial Sex Acts           1          1
# 11                                             Other5          26         27
# 12                           Crimes against property:        3115       3115
# 13                                            Robbery         157        157
# 14                                           Burglary         145        145
# 15                                      Larceny-theft         326        326
# 16                                Motor vehicle theft          41         41
# 17                                              Arson          42         42
# 18                       Destruction/damage/vandalism        2325       2325
# 19                                             Other5          79         79
# 20                            Crimes against society5         238        238
# 21  1 The actual number of incidents is 7,175. How...         NaN        NaN
# 22  2 The term victim may refer to an individual, ...         NaN        NaN
# 23  3 The term known offender does not imply the s...         NaN        NaN
# 24  4 The figures shown in this row for the offens...         NaN        NaN
# 25  5 Includes additional offenses collected in th...         NaN        NaN
#
#    Unnamed: 3         Unnamed: 4
# 0         NaN                NaN
# 1         NaN                NaN
# 2    Victims2  Known\noffenders3
# 3        8828               6370
# 4        5084               4442
# 5          15                 15
# 6          23                 30
# 7         990               1051
# 8        1745               1725
# 9        2283               1588
# 10          1                  0
# 11         27                 33
# 12       3506               1933
# 13        171                288
# 14        185                 98
# 15        379                249
# 16         44                 25
# 17         59                 34
# 18       2585               1182
# 19         83                 57
# 20        238                284
# 21        NaN                NaN
# 22        NaN                NaN
# 23        NaN                NaN
# 24        NaN                NaN
# 25        NaN                NaN

# %%
table2 = [t2_17]
for index, df in enumerate(table2):
    table2[index] = df.rename(columns={"Table 2  ": "Offense type", "Unnamed: 1": "Incidents", "Unnamed: 2": "Offenses", 
                  "Unnamed: 3": "Victims", "Unnamed: 4": "Known Offenders"})
    table2[index] = table2[index].loc[4:20, :].set_index('Offense type')
    table2[index] = table2[index].rename(index=lambda s: re.sub(r'\d+$', '', s)) #removing any digits inside the index column 
[t2_17] = table2

# %%
#t2_17

# %%
#drop rows in tables
table2 = [t2_17]
for index, df in enumerate(table2):
    df = df.drop([df.index[0], df.index[8]])
    table2[index] = df
[t2_17] = table2

# %%
#t2_18

# %%
table2 = [t2_17]
for index, df in enumerate(table2):
    table2[index] = df.rename(columns={"Table 2  ": "Offense type", "Unnamed: 1": "Incidents", "Unnamed: 2": "Offenses", 
                  "Unnamed: 3": "Victims", "Unnamed: 4": "Known Offenders"})
    table2[index] = table2[index].loc[4:20, :].set_index('Offense type')
    table2[index] = table2[index].rename(index=lambda s: re.sub(r'\d+$', '', s)) #removing any digits inside the index column 
[t2_17] = table2
